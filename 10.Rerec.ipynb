# %%
# %cd data
# !python pca.py
# Out:
# [Errno 2] No such file or directory: 'data'
# /content

# %%
# !pip uninstall -y faiss faiss-cpu faiss-gpu faiss-gpu-cu11 faiss-gpu-cu12
# !pip install --no-cache-dir "faiss-gpu-cu12>=1.8.0,<2.0.0"
# Out:
# WARNING: Skipping faiss as it is not installed.
# WARNING: Skipping faiss-cpu as it is not installed.
# WARNING: Skipping faiss-gpu as it is not installed.
# WARNING: Skipping faiss-gpu-cu11 as it is not installed.
# WARNING: Skipping faiss-gpu-cu12 as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 MB 189.7 MB/s eta 0:00:00
# ...

# %%
# %cd data
# !python retrival_users.py
# Out:
# /content/drive/MyDrive/LLM_ESR_2023_v4/data
# [inter_seq] users=657203
# [FAISS] GPU index
# Saved: ./movie/handled/sim_user_100.pkl (657203, 100)
# Saved: ./movie/handled/sim_users_uid_100.pkl (657203, 100)
# Saved order: ./movie/handled/user_order_ids.json 657203 users

# %%
# !pip uninstall -y tensorflow tensorflow-cpu tb-nightly tensorboard tensorboard-data-server tensorboard-plugin-wit
# !pip install -U "numpy>=1.26.4" "tensorboard>=2.17.0"
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# WARNING: Skipping tensorflow-cpu as it is not installed.
# WARNING: Skipping tb-nightly as it is not installed.
# Found existing installation: tensorboard 2.19.0
# Uninstalling tensorboard-2.19.0:
#   Successfully uninstalled tensorboard-2.19.0
# Found existing installation: tensorboard-data-server 0.7.2
# Uninstalling tensorboard-data-server-0.7.2:
#   Successfully uninstalled tensorboard-data-server-0.7.2
# WARNING: Skipping tensorboard-plugin-wit as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 112.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 126.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 86.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
# ...

# %%
# !bash experiments/beauty.bash --dataset beauty
# print("")
